# %% [markdown]
# # **TOP 2 VISUALIZATION LIBRARY AND THEIR APPLICATIONS**
#
# *I'm going to talk about 2 libraries to help us with data visualization by Python and we will see some examples here.*
#
# **These 2 library:**
# * Matplotlib
# * Seaborn

# %% [markdown]
# **1. INTRODUCTION**
#
# **2. SIMPLE EXAMPLES**
#
# **3. EXAMPLES WITH A DATASET**

# %% [markdown]
# ## **1. INTRODUCTION**
#
# What is **matplotlib**?
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# (If you want to visit Matplotlib's own page: https://matplotlib.org/)

# %% [markdown]
# what is **seaborn**?
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# (If you want to visit Seaborn's own page: https://seaborn.pydata.org/)

# %% [markdown]
# ## **2. SIMPLE EXAMPLES**

# %% [markdown]
# ### MATPLOTLIB
# **Here's what we can do using matplotlib:**
# * **Basic**: Basic plot types, usually y versus x.
# * **Plots of arrays and fields**: Plotting for arrays of data Z(x, y) and fields U(x, y), V(x, y).
# * **Statistics plots**: Plots for statistical analysis.
# * **Unstructured coordinates** : Sometimes we collect data z at coordinates (x,y) and want to visualize as a contour. Instead of gridding the data and then using contour, we can use a triangulation algorithm and fill the triangles.
# * **3D** : 3D plots using the mpl_toolkits.mplot3d library.

# %% [markdown]
# *Reminder:* At this step, these codes may seen useless but these are good for getting into the swing of visualization.

# %%
# PLOT

import matplotlib.pyplot as plt
import numpy as np

# make data
x = np.linspace(0, 20, 1000)
y = 4 + 3 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(x, y, linewidth=2.0)

ax.set(xlim=(0, 8), xticks=np.arange(1, 10),
       ylim=(0, 8), yticks=np.arange(1, 10))

plt.grid(True)
plt.show()

# %%
# BAR

# make data:
np.random.seed(3)
x = 0.5 + np.arange(20)
y = np.random.uniform(2, 8, len(x))

# plot
fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="red", linewidth=0.7)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

print("x:", x,"\n", "y:",y)
plt.grid(True)
plt.show()
# Out:
# x: [ 0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5  8.5  9.5 10.5 11.5 12.5 13.5
#  14.5 15.5 16.5 17.5 18.5 19.5]
#  y: [5.30478742 6.24888694 3.74542843 5.06496563 7.35768173 7.37775853
#  2.75351186 3.24345727 2.30880322 4.64485906 2.17925727 4.74099935
#  5.89486429 3.6709237  6.05752941 5.5451769  2.14389129 5.35312453
#  3.55551468 4.49060718]

# %%
#SCATTER

# make the data
np.random.seed(3)
x = 4 + np.random.normal(0, 2, 36)
y = 4 + np.random.normal(0, 2, len(x))
# size and color:
sizes = np.random.uniform(16, 100, len(x))
colors = np.random.uniform(16, 100, len(x))

# plot
fig, ax = plt.subplots()

ax.scatter(x, y, s=sizes, c=colors, vmin=-50, vmax=50)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.grid(True)
plt.show()

# %%
#HISTOGRAM

# make data
np.random.seed(1)
x = x = 4 + np.random.normal(0, 2, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=12, color= "yellow", linewidth=0.7, edgecolor="red")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.grid(True)
plt.show()

# %%
# PIE CHART

# make data
x = [1, 2, 3, 4, 5]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.8, len(x)))

# plot
fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=4, center=(5, 5),
       wedgeprops={"linewidth": 2, "edgecolor": "white"}, frame=True)

plt.show()

# %%
# 2D HISTOGRAM : NOISE 

# make data: correlated + noise
np.random.seed(1)
x = np.random.randn(5000)
y = 1.2 * x + np.random.randn(5000) / 3

# plot:
fig, ax = plt.subplots()

ax.hist2d(x, y, bins=(np.arange(-3, 3, 0.1), np.arange(-3, 3, 0.1)))
ax.set(xlim=(-2, 2), ylim=(-3, 3))

plt.grid()
plt.show()

# %%
#3 SURFACE
from matplotlib import cm

# Make data
X = np.arange(-100, 100, 20)
Y = np.arange(-100, 100, 20)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min()* 3 , cmap=cm.Blues)

ax.set(xticklabels=["x"],
       yticklabels=["y"],
       zticklabels=["z"])

plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   app.launch_new_instance()

# %% [markdown]
# ### SEABORN

# %%
import seaborn as sns
from matplotlib import rcParams
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
p = sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",markers=True,
             data=fmri)

plt.subplots(figsize = (5,5))
# Out:
# (<Figure size 360x360 with 1 Axes>, <AxesSubplot:>)

# %%
#Grouped boxplot

sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "y"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
#Annotated heatmaps
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
#Scatterplot with varying point sizes and hues
sns.set_theme(style="white")

# Load the example mpg dataset
mpg = sns.load_dataset("mpg")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=mpg)
plt.grid()
plt.acorrshow()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_18/2381193624.py in <module>
#      10             height=6, data=mpg)
#      11 plt.grid()
# ---> 12 plt.acorrshow()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'acorrshow'

# %%
#Multiple Linear Regression

# Load the penguins dataset
penguins = sns.load_dataset("penguins")

# Plot sepal width as a function of sepal_length across days
g = sns.lmplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="species",
    height=5
)

# Use more informative axis labels than are provided by default
g.set_axis_labels("Snoot length (mm)", "Snoot depth (mm)")

# %% [markdown]
# ## **3. EXAMPLES WITH A DATASET**

# %% [markdown]
# ### PRE-PROCESSING

# %%
#importing libraries that we use:
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
data = pd.read_excel("../input/population-growth-vs-forest-cover/forest-cover-v1.xlsx")

# %%
data.head()
# Out:
#   Country Name Country Code           Capital      Continent  Area (kmÂ²)  \
# 0        Aruba          ABW        Oranjestad  North America          180
# 1  Afghanistan          AFG             Kabul           Asia       652230
# 2       Angola          AGO            Luanda         Africa      1246700
# 3      Albania          ALB            Tirana         Europe        28748
# 4      Andorra          AND  Andorra la Vella         Europe          468
#
#    Population Density (per kmÂ²)  Population Growth Rate  \
# 0                       591.3611                  0.9991
# 1                        63.0587                  1.0257
# 2                        28.5466                  1.0315
# 3                        98.8702                  0.9957
# 4                       170.5641                  1.0100
#
#    World Population Percentage  Population Rank  Forest Area 1990  ...  \
# 0                         0.00              198          2.333333  ...
# ...

# %% [markdown]
# We don't see the whole columns because there are "forest area" since 1990 to 2020.

# %% [markdown]
# Firstly, we should try to understand the dataset before starting visualization.
#
# **About Dataset:**
# * Country Name :Country name
# * Country Code :Country Code
# * Capital :Capital of the country
# * Continent :Continent of the country
# * Area (kmÂ²) :Area of the country (kmÂ²)
# * Population Density (per kmÂ²) :Population Density of the country (per kmÂ²)
# * Population Growth Rate :Population Growth Rate of the country
# * World Population Percentage :World Population Percentage
# * Population Rank :Population Rank
# * Forest Area 1990 :Forest coverage recorded in 1990 (% of land area)
# * ...

# %%
data.shape
# Out:
# (214, 40)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country Name                   214 non-null    object
#  1   Country Code                   214 non-null    object
#  2   Capital                        214 non-null    object
#  3   Continent                      214 non-null    object
#  4   Area (kmÂ²)                    214 non-null    int64
#  5   Population Density (per kmÂ²)  214 non-null    float64
#  6   Population Growth Rate         214 non-null    float64
#  7   World Population Percentage    214 non-null    float64
#  8   Population Rank                214 non-null    int64
#  9   Forest Area 1990               204 non-null    float64
#  10  Forest Area 1991               207 non-null    float64
#  11  Forest Area 1992               207 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# Country Name                      0
# Country Code                      0
# Capital                           0
# Continent                         0
# Area (kmÂ²)                       0
# Population Density (per kmÂ²)     0
# Population Growth Rate            0
# World Population Percentage       0
# Population Rank                   0
# Forest Area 1990                 10
# Forest Area 1991                  7
# Forest Area 1992                  7
# Forest Area 1993                  7
# Forest Area 1994                  7
# Forest Area 1995                  7
# Forest Area 1996                  7
# Forest Area 1997                  7
# Forest Area 1998                  7
# Forest Area 1999                  7
# Forest Area 2000                  3
# Forest Area 2001                  6
# Forest Area 2002                  6
# Forest Area 2003                  6
# Forest Area 2004                  6
# Forest Area 2005                  6
# Forest Area 2006                  6
# ...

# %% [markdown]
# I will not deal with missing data as there is missing data in a wide variety of places. Instead, I will first try to visualize by decomposing according to continents.

# %%
data["Continent"].unique()
# Out:
# array(['North America', 'Asia', 'Africa', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# Let's reduce the "Forest Area" columns to make our job easier:
# * 1990-1995-2000-2005-2010-2015-2020

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Capital', 'Continent', 'Area (kmÂ²)',
#        'Population Density (per kmÂ²)', 'Population Growth Rate',
#        'World Population Percentage', 'Population Rank', 'Forest Area 1990',
#        'Forest Area 1991', 'Forest Area 1992', 'Forest Area 1993',
#        'Forest Area 1994', 'Forest Area 1995', 'Forest Area 1996',
#        'Forest Area 1997', 'Forest Area 1998', 'Forest Area 1999',
#        'Forest Area 2000', 'Forest Area 2001', 'Forest Area 2002',
#        'Forest Area 2003', 'Forest Area 2004', 'Forest Area 2005',
#        'Forest Area 2006', 'Forest Area 2007', 'Forest Area 2008',
#        'Forest Area 2009', 'Forest Area 2010', 'Forest Area 2011',
#        'Forest Area 2012', 'Forest Area 2013', 'Forest Area 2014',
#        'Forest Area 2015', 'Forest Area 2016', 'Forest Area 2017',
#        'Forest Area 2018', 'Forest Area 2019', 'Forest Area 2020'],
#       dtype='object')

# %%
i = "Forest Area"
[int(s) for s in i.split() if s.isdigit()]
# Out:
# []

# %%
droped_years = []
for i in data.columns:
    year = [int(s) for s in i.split() if s.isdigit()]
    if year != []:
        year = [int(s) for s in i.split() if s.isdigit()][0]
        if (year % 5) != 0:
            droped_years.append(i)
        
        
print(droped_years)
# Out:
# ['Forest Area 1991', 'Forest Area 1992', 'Forest Area 1993', 'Forest Area 1994', 'Forest Area 1996', 'Forest Area 1997', 'Forest Area 1998', 'Forest Area 1999', 'Forest Area 2001', 'Forest Area 2002', 'Forest Area 2003', 'Forest Area 2004', 'Forest Area 2006', 'Forest Area 2007', 'Forest Area 2008', 'Forest Area 2009', 'Forest Area 2011', 'Forest Area 2012', 'Forest Area 2013', 'Forest Area 2014', 'Forest Area 2016', 'Forest Area 2017', 'Forest Area 2018', 'Forest Area 2019']

# %%
df = data.drop(droped_years, axis=1)
df.head()
# Out:
#   Country Name Country Code           Capital      Continent  Area (kmÂ²)  \
# 0        Aruba          ABW        Oranjestad  North America          180
# 1  Afghanistan          AFG             Kabul           Asia       652230
# 2       Angola          AGO            Luanda         Africa      1246700
# 3      Albania          ALB            Tirana         Europe        28748
# 4      Andorra          AND  Andorra la Vella         Europe          468
#
#    Population Density (per kmÂ²)  Population Growth Rate  \
# 0                       591.3611                  0.9991
# 1                        63.0587                  1.0257
# 2                        28.5466                  1.0315
# 3                        98.8702                  0.9957
# 4                       170.5641                  1.0100
#
#    World Population Percentage  Population Rank  Forest Area 1990  \
# 0                         0.00              198          2.333333
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Capital', 'Continent', 'Area (kmÂ²)',
#        'Population Density (per kmÂ²)', 'Population Growth Rate',
#        'World Population Percentage', 'Population Rank', 'Forest Area 1990',
#        'Forest Area 1995', 'Forest Area 2000', 'Forest Area 2005',
#        'Forest Area 2010', 'Forest Area 2015', 'Forest Area 2020'],
#       dtype='object')

# %% [markdown]
# ### VISUALIZATION

# %%
# data visualization libraries 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#Comparison of forest areas by continents in 2020: BOXPLOT

sns.boxplot(x="Forest Area 2020", y="Continent", data=df,
            whis=[0, 100], width=.6, palette="vlag")
# Add in points to show each observation
sns.stripplot(x="Forest Area 2020", y="Continent", data=df,
              size=4, color=".3", linewidth=0)
# Out:
# <AxesSubplot:xlabel='Forest Area 2020', ylabel='Continent'>

# %%
#Comparison by continent, how has forest area changed over the years?
years = ['Forest Area 1990','Forest Area 1995', 'Forest Area 2000',
         'Forest Area 2005','Forest Area 2010', 'Forest Area 2015', 'Forest Area 2020']
for i in years:
    sns.boxplot(x=i, y="Continent", data=df,
                whis=[0, 100], width=.6, palette="vlag")
    
    sns.stripplot(x=i, y="Continent", data=df,
              size=4, color=".3", linewidth=0)
    plt.show()

# %%
#New DataFrame which has index as a "Country Name"
data = df.set_index("Country Name")
a = data.loc["China"]
a
# Out:
# Country Code                           CHN
# Capital                            Beijing
# Continent                             Asia
# Area (kmÂ²)                        9706961
# Population Density (per kmÂ²)     146.8933
# Population Growth Rate                 1.0
# World Population Percentage          17.88
# Population Rank                          1
# Forest Area 1990                 16.673325
# Forest Area 1995                 17.726847
# Forest Area 2000                 18.780497
# Forest Area 2005                 20.033048
# Forest Area 2010                 21.285597
# Forest Area 2015                 22.313094
# Forest Area 2020                 23.340596
# Name: China, dtype: object

# %%
# Change in forest areas of 10 countries with the highest population growth rate:
top_ten = df.sort_values("Population Rank")["Country Name"][0:10]
top_ten
# Out:
# 35                  China
# 88                  India
# 201         United States
# 86              Indonesia
# 148              Pakistan
# 140               Nigeria
# 26                 Brazil
# 17             Bangladesh
# 163    Russian Federation
# 124                Mexico
# Name: Country Name, dtype: object

# %%
top_ten = top_ten.values.tolist()
top_ten
# Out:
# ['China',
#  'India',
#  'United States',
#  'Indonesia',
#  'Pakistan',
#  'Nigeria',
#  'Brazil',
#  'Bangladesh',
#  'Russian Federation',
#  'Mexico']

# %%
x = []
for i in top_ten:
    y = data.loc[i][14] - data.loc[i][8]
    x.append(y)
print(x)
# Out:
# [6.667270269876969, 2.765379945445801, 0.8446182023717697, -16.365933882390692, 4.64554794520548, -5.379118767636182, -11.040542513047164, -0.2837059230237369, 0.42787068391982075, -2.5204197638828134]

# %%
# x includes Forest Area 2020 - Forest Area 1990
# top_ten includes name of the countries which has highest population rank
fig, ax = plt.subplots()
new_df = pd.DataFrame({'Timing_Event':top_ten, 'Diff_Latency':x})
new_df['sign'] = new_df['Diff_Latency'] > 0

new_df['Diff_Latency'].plot(kind='bar', color=new_df.sign.map({True: (1.0, 0, 0, 0.7), False: (0, 0.6, 0, 0.7)}), 
                      ax=ax)
ax.axhline(0, color='k')

ax.set_xticklabels(top_ten) # changing x numereic labels into countries
# Out:
# [Text(0, 0, 'China'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'United States'),
#  Text(3, 0, 'Indonesia'),
#  Text(4, 0, 'Pakistan'),
#  Text(5, 0, 'Nigeria'),
#  Text(6, 0, 'Brazil'),
#  Text(7, 0, 'Bangladesh'),
#  Text(8, 0, 'Russian Federation'),
#  Text(9, 0, 'Mexico')]

# %%
#Top 10 countries with the highest Human population / Country Area ratio
top_ten2 = df.sort_values("Population Density (per kmÂ²)")["Country Name"][0:10]
top_ten2
# Out:
# 77     Greenland
# 131     Mongolia
# 137      Namibia
# 10     Australia
# 92       Iceland
# 80        Guyana
# 177     Suriname
# 32        Canada
# 109        Libya
# 30      Botswana
# Name: Country Name, dtype: object

# %%
data.head()
# Out:
#              Country Code           Capital      Continent  Area (kmÂ²)  \
# Country Name
# Aruba                 ABW        Oranjestad  North America          180
# Afghanistan           AFG             Kabul           Asia       652230
# Angola                AGO            Luanda         Africa      1246700
# Albania               ALB            Tirana         Europe        28748
# Andorra               AND  Andorra la Vella         Europe          468
#
#               Population Density (per kmÂ²)  Population Growth Rate  \
# Country Name
# Aruba                              591.3611                  0.9991
# Afghanistan                         63.0587                  1.0257
# Angola                              28.5466                  1.0315
# Albania                             98.8702                  0.9957
# Andorra                            170.5641                  1.0100
#
#               World Population Percentage  Population Rank  Forest Area 1990  \
# ...

# %%
a = data.sort_values("Population Density (per kmÂ²)")
a.head()
# Out:
#              Country Code      Capital      Continent  Area (kmÂ²)  \
# Country Name
# Greenland             GRL         Nuuk  North America      2166086
# Mongolia              MNG  Ulaanbaatar           Asia      1564110
# Namibia               NAM     Windhoek         Africa       825615
# Australia             AUS     Canberra        Oceania      7692024
# Iceland               ISL   ReykjavÃ­k         Europe       103000
#
#               Population Density (per kmÂ²)  Population Growth Rate  \
# Country Name
# Greenland                            0.0261                  1.0040
# Mongolia                             2.1727                  1.0151
# Namibia                              3.1092                  1.0146
# Australia                            3.4032                  1.0099
# Iceland                              3.6204                  1.0069
#
#               World Population Percentage  Population Rank  Forest Area 1990  \
# Country Name
# ...

# %%
x = a.columns[0:8]

# %%
a.drop(x, axis=1, inplace=True)
a.head()
# Out:
#               Forest Area 1990  Forest Area 1995  Forest Area 2000  \
# Country Name
# Greenland             0.000644          0.000644          0.000536
# Mongolia              9.238137          9.209783          9.181428
# Namibia              10.651374         10.220125          9.788876
# Australia            17.427359         17.292757         17.158156
# Iceland               0.170274          0.233915          0.297556
#
#               Forest Area 2005  Forest Area 2010  Forest Area 2015  \
# Country Name
# Greenland             0.000536          0.000536          0.000536
# Mongolia              9.155681          9.129934          9.104691
# Namibia               9.357622          8.926369          8.495123
# Australia            17.010544         16.862932         17.324825
# Iceland               0.371571          0.445586          0.480399
#
#               Forest Area 2020
# Country Name
# Greenland             0.000536
# Mongolia              9.101130
# ...

# %%
b = a.iloc[0:10].T
b
# Out:
# Country Name      Greenland  Mongolia    Namibia  Australia   Iceland  \
# Forest Area 1990   0.000644  9.238137  10.651374  17.427359  0.170274
# Forest Area 1995   0.000644  9.209783  10.220125  17.292757  0.233915
# Forest Area 2000   0.000536  9.181428   9.788876  17.158156  0.297556
# Forest Area 2005   0.000536  9.155681   9.357622  17.010544  0.371571
# Forest Area 2010   0.000536  9.129934   8.926369  16.862932  0.445586
# Forest Area 2015   0.000536  9.104691   8.495123  17.324825  0.480399
# Forest Area 2020   0.000536  9.101130   8.063866  17.421315  0.509273
#
# Country Name         Guyana   Suriname     Canada     Libya   Botswana
# Forest Area 1990  94.499111  98.574551  38.845512  0.123328  33.179292
# Forest Area 1995  94.402769  98.456731  38.819247  0.123328  32.135585
# Forest Area 2000  94.306426  98.338910  38.792982  0.123328  31.091878
# Forest Area 2005  94.193625  98.207468  38.766226  0.123328  30.048171
# ...

# %%
b.index
# Out:
# Index(['Forest Area 1990', 'Forest Area 1995', 'Forest Area 2000',
#        'Forest Area 2005', 'Forest Area 2010', 'Forest Area 2015',
#        'Forest Area 2020'],
#       dtype='object')

# %%
b.index = ['1990', '1995', '2000','2005', '2010', '2015','2020']
b.index
# Out:
# Index(['1990', '1995', '2000', '2005', '2010', '2015', '2020'], dtype='object')

# %%
c= b.columns.values.tolist()
c
# Out:
# ['Greenland',
#  'Mongolia',
#  'Namibia',
#  'Australia',
#  'Iceland',
#  'Guyana',
#  'Suriname',
#  'Canada',
#  'Libya',
#  'Botswana']

# %%
b.head()
# Out:
# Country Name  Greenland  Mongolia    Namibia  Australia   Iceland     Guyana  \
# 1990           0.000644  9.238137  10.651374  17.427359  0.170274  94.499111
# 1995           0.000644  9.209783  10.220125  17.292757  0.233915  94.402769
# 2000           0.000536  9.181428   9.788876  17.158156  0.297556  94.306426
# 2005           0.000536  9.155681   9.357622  17.010544  0.371571  94.193625
# 2010           0.000536  9.129934   8.926369  16.862932  0.445586  94.080823
#
# Country Name   Suriname     Canada     Libya   Botswana
# 1990          98.574551  38.845512  0.123328  33.179292
# 1995          98.456731  38.819247  0.123328  32.135585
# 2000          98.338910  38.792982  0.123328  31.091878
# 2005          98.207468  38.766226  0.123328  30.048171
# 2010          98.076026  38.739471  0.123328  29.004464

# %%
b.Canada.plot(legend=True) #plot Canada column
plt.show()

# %%
for i in b.columns:
    b[i].plot(legend=True)
    plt.xlabel = ["Years"]
    plt.ylabel = ["Forest Area"]
    plt.show()

# %%
#Other Method 
b.plot(subplots=True, figsize=(10, 8), layout=(5, 2))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)
